# %% [markdown]
# # Fazendo testes com o Pandas
#
# criando um DataFrame apartir de um **JSON** dado por:
#
# ```JSON
# {
#     "status": "sucess",
#     "messagem": "todos as etapas obtidas com sucesso!",
#     "code": 200,
#     "dados": [
#         {
#             "id": 1,
#             "distancia": 1000.0,
#             "tempo_corrido": "12:27:06",
#             "tempo_exato": "12:27:07",
#             "descricao": "Corrida",
#             "treino": 1
#         },
#         {
#             "id": 2,
#             "distancia": 1000.0,
#             "tempo_corrido": "12:27:42",
#             "tempo_exato": "12:27:43",
#             "descricao": "Corrida",
#             "treino": 1
#         },
#         {
#             "id": 3,
#             "distancia": 1000.0,
#             "tempo_corrido": "12:27:57",
#             "tempo_exato": "12:27:57",
#             "descricao": "Corrida",
#             "treino": 1
#         },
#         {
#             "id": 4,
#             "distancia": 200.0,
#             "tempo_corrido": "00:03.01",
#             "tempo_exato": "00:03.01",
#             "descricao": "corrida",
#             "treino": 11
#         },
#         {
#             "id": 5,
#             "distancia": 200.0,
#             "tempo_corrido": "00:05.65",
#             "tempo_exato": "00:02.64",
#             "descricao": "descanco",
#             "treino": 11
#         },
#         {
#             "id": 6,
#             "distancia": 200.0,
#             "tempo_corrido": "00:07.83",
#             "tempo_exato": "00:02.18",
#             "descricao": "corrida",
#             "treino": 11
#         },
#         {
#             "id": 7,
#             "distancia": 200.0,
#             "tempo_corrido": "00:09.95",
#             "tempo_exato": "00:02.12",
#             "descricao": "descanco",
#             "treino": 11
#         },
#         {
#             "id": 8,
#             "distancia": 200.0,
#             "tempo_corrido": "00:10.50",
#             "tempo_exato": "00:00.55",
#             "descricao": "corrida",
#             "treino": 11
#         },
#         {
#             "id": 9,
#             "distancia": 2000.0,
#             "tempo_corrido": "00:05.01",
#             "tempo_exato": "00:53.01",
#             "descricao": "corrida",
#             "treino": 12
#         },
#         {
#             "id": 10,
#             "distancia": 2000.0,
#             "tempo_corrido": "00:05.65",
#             "tempo_exato": "00:02.64",
#             "descricao": "corrida",
#             "treino": 12
#         },
#         {
#             "id": 11,
#             "distancia": 2000.0,
#             "tempo_corrido": "00:07.83",
#             "tempo_exato": "00:02.18",
#             "descricao": "corrida",
#             "treino": 12
#         },
#         {
#             "id": 12,
#             "distancia": 2000.0,
#             "tempo_corrido": "00:09.95",
#             "tempo_exato": "00:02.12",
#             "descricao": "corrida",
#             "treino": 12
#         },
#         {
#             "id": 13,
#             "distancia": 2000.0,
#             "tempo_corrido": "00:10.49",
#             "tempo_exato": "00:00.54",
#             "descricao": "corrida",
#             "treino": 12
#         },
#         {
#             "id": 14,
#             "distancia": 3000.0,
#             "tempo_corrido": "3.01",
#             "tempo_exato": "3.01",
#             "descricao": "corrida",
#             "treino": 15
#         },
#         {
#             "id": 15,
#             "distancia": 3000.0,
#             "tempo_corrido": "5.65",
#             "tempo_exato": "2.64",
#             "descricao": "corrida",
#             "treino": 15
#         },
#         {
#             "id": 16,
#             "distancia": 3000.0,
#             "tempo_corrido": "7.83",
#             "tempo_exato": "2.18",
#             "descricao": "corrida",
#             "treino": 15
#         },
#         {
#             "id": 17,
#             "distancia": 3000.0,
#             "tempo_corrido": "9.95",
#             "tempo_exato": "2.12",
#             "descricao": "corrida",
#             "treino": 15
#         },
#         {
#             "id": 18,
#             "distancia": 3000.0,
#             "tempo_corrido": "10.49",
#             "tempo_exato": "0.54",
#             "descricao": "corrida",
#             "treino": 15
#         }
#     ]
# }
# ```

# %%
import pandas as pd

dados_json = {
    "status": "sucess",
    "messagem": "todos as etapas obtidas com sucesso!",
    "code": 200,
    "dados": [
        {
            "id": 1,
            "distancia": 1000.0,
            "tempo_corrido": "12:27:06",
            "tempo_exato": "12:27:07",
            "descricao": "Corrida",
            "treino": 1
        },
        {
            "id": 2,
            "distancia": 1000.0,
            "tempo_corrido": "12:27:42",
            "tempo_exato": "12:27:43",
            "descricao": "Corrida",
            "treino": 1
        },
        {
            "id": 3,
            "distancia": 1000.0,
            "tempo_corrido": "12:27:57",
            "tempo_exato": "12:27:57",
            "descricao": "Corrida",
            "treino": 1
        },
        {
            "id": 4,
            "distancia": 200.0,
            "tempo_corrido": "00:03.01",
            "tempo_exato": "00:03.01",
            "descricao": "corrida",
            "treino": 11
        },
        {
            "id": 5,
            "distancia": 200.0,
            "tempo_corrido": "00:05.65",
            "tempo_exato": "00:02.64",
            "descricao": "descanco",
            "treino": 11
        },
        {
            "id": 6,
            "distancia": 200.0,
            "tempo_corrido": "00:07.83",
            "tempo_exato": "00:02.18",
            "descricao": "corrida",
            "treino": 11
        },
        {
            "id": 7,
            "distancia": 200.0,
            "tempo_corrido": "00:09.95",
            "tempo_exato": "00:02.12",
            "descricao": "descanco",
            "treino": 11
        },
        {
            "id": 8,
            "distancia": 200.0,
            "tempo_corrido": "00:10.50",
            "tempo_exato": "00:00.55",
            "descricao": "corrida",
            "treino": 11
        },
        {
            "id": 9,
            "distancia": 2000.0,
            "tempo_corrido": "00:05.01",
            "tempo_exato": "00:53.01",
            "descricao": "corrida",
            "treino": 12
        },
        {
            "id": 10,
            "distancia": 2000.0,
            "tempo_corrido": "00:05.65",
            "tempo_exato": "00:02.64",
            "descricao": "corrida",
            "treino": 12
        },
        {
            "id": 11,
            "distancia": 2000.0,
            "tempo_corrido": "00:07.83",
            "tempo_exato": "00:02.18",
            "descricao": "corrida",
            "treino": 12
        },
        {
            "id": 12,
            "distancia": 2000.0,
            "tempo_corrido": "00:09.95",
            "tempo_exato": "00:02.12",
            "descricao": "corrida",
            "treino": 12
        },
        {
            "id": 13,
            "distancia": 2000.0,
            "tempo_corrido": "00:10.49",
            "tempo_exato": "00:00.54",
            "descricao": "corrida",
            "treino": 12
        },
        {
            "id": 14,
            "distancia": 3000.0,
            "tempo_corrido": "3.01",
            "tempo_exato": "3.01",
            "descricao": "corrida",
            "treino": 15
        },
        {
            "id": 15,
            "distancia": 3000.0,
            "tempo_corrido": "5.65",
            "tempo_exato": "2.64",
            "descricao": "corrida",
            "treino": 15
        },
        {
            "id": 16,
            "distancia": 3000.0,
            "tempo_corrido": "7.83",
            "tempo_exato": "2.18",
            "descricao": "corrida",
            "treino": 15
        },
        {
            "id": 17,
            "distancia": 3000.0,
            "tempo_corrido": "9.95",
            "tempo_exato": "2.12",
            "descricao": "corrida",
            "treino": 15
        },
        {
            "id": 18,
            "distancia": 3000.0,
            "tempo_corrido": "10.49",
            "tempo_exato": "0.54",
            "descricao": "corrida",
            "treino": 15
        }
    ]
}

# %% [markdown]
# Obtendo apenas os dados importantes do JSON.

# %%
dados = dados_json["dados"]
dados
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dados = dados_json["dados"]
#       2 dados
#
# NameError: name 'dados_json' is not defined
